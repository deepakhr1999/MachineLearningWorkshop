# %%
import numpy as np
import pandas as pd
np.set_printoptions(precision=3)
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
np.random.seed(0)

# %%
M = 100
x = (np.random.rand(M, 1) * 2 - 1) * 3

features = np.concatenate([np.ones_like(x), x, x**2, x**3], axis=1)
w = np.array([[1], [2], [3], [4]])
noise = np.random.randn(M, 1)
y = features.dot(w) +  noise * 8
y = y.flatten()

# no specific rule for multiplying max by 2, this is just an example.
print(x.shape, y.shape)

fig, ax = plt.subplots(figsize=(10, 8))
plt.scatter(x, y, ls='dotted');
plt.title('Example data with outliers', fontsize=18)
plt.xlabel('Data', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.show()
# Out:
# (100, 1) (100,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X.astype(np.float32), y.astype(np.float32), test_size=0.25, random_state=42)

model = Ridge(alpha=.0)
model.fit(X_train, y_train)

w = np.array([model.intercept_, model.coef_[0]])
print(f'intercept is {w[1]}, coefficient is {w[0]}')
# Out:
# intercept is 11.619877815246582, coefficient is -112.30902099609375

# %%
plotX = np.array([0, 100])
plotY = w[0] + w[1] * plotX


fig, ax = plt.subplots(figsize=(10, 8))
plt.scatter(X, y, ls='dotted');
plt.title('Example data with outliers', fontsize=18)
plt.xlabel('Data', fontsize=15)
plt.ylabel('Target', fontsize=15);
plt.plot(plotX, plotY, color='red')
plt.show()

# %%
w = np.array([[1], [2], [3], [4]])
w.shape
# Out:
# (4, 1)

# %%
x = np.random.rand(M, 1) * 100 - 50

features = np.concatenate([np.ones_like(x), x, x**2, x**3], axis=1)
features.shape
# Out:
# (100, 4)
